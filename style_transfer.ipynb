# %%
import torch 
from torchvision import transforms , models 
from PIL import Image 
import matplotlib.pyplot as plt
import numpy as np

# %%
device = ("cuda" if torch.cuda.is_available() else "cpu")

# %%
#load and train
model = models.vgg19(pretrained=True).features #why vgg19- learns in different scale, captures more details
for p in model.parameters():
    p.requires_grad = False
model.to(device)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (17): ReLU(inplace=True)
#   (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (24): ReLU(inplace=True)
#   (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (26): ReLU(inplace=True)
#   (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
#   (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (31): ReLU(inplace=True)
#   (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (33): ReLU(inplace=True)
#   (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (35): ReLU(inplace=True)
#   (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
def model_activations(input,model):
    layers = {
    '0' : 'conv1_1',
    '5' : 'conv2_1',
    '10': 'conv3_1',
    '19': 'conv4_1',
    '21': 'conv4_2',
    '28': 'conv5_1'
    }
    features = {}
    x = input
    x = x.unsqueeze(0)
    for name,layer in model._modules.items():
        x = layer(x)
        if name in layers:
            features[layers[name]] = x 
    
    return features

# %%
transform = transforms.Compose([transforms.Resize(300),
                              transforms.ToTensor(),
                              transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])

# %%
content = Image.open("content.jpg").convert("RGB")
content = transform(content).to(device)
print("COntent shape => ", content.shape)
style = Image.open("style.jpg").convert("RGB")
style = transform(style).to(device)
# Out:
# COntent shape =>  torch.Size([3, 450, 300])

# %%
#inp-pytorch tensor and convert it to a form that can be printed using matplotlib 
def imcnvt(image):
    x = image.to("cpu").clone().detach().numpy().squeeze()
    x = x.transpose(1,2,0)
    x = x*np.array((0.5,0.5,0.5)) + np.array((0.5,0.5,0.5))
    return np.clip(x,0,1)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.imshow(imcnvt(content),label = "Content")
ax2.imshow(imcnvt(style),label = "Style")
plt.show()

# %%
#gm-correlation bw ftr matrices of the style img(matrix multiplication of ftr with its transpose)
def gram_matrix(imgfeature):
    _,d,h,w = imgfeature.size()
    imgfeature = imgfeature.view(d,h*w)
    gram_mat = torch.mm(imgfeature,imgfeature.t())
    
    return gram_mat

# %%
target = content.clone().requires_grad_(True).to(device) #ti-combine style and content

# %%
#set device to cuda if available
print("device = ",device)

#capture style and content ftrs outside of optimization loop
#here content and style img is constant
style_features = model_activations(style,model)
content_features = model_activations(content,model)
# Out:
# device =  cpu

# %%
style_wt_meas = {"conv1_1" : 1.0, 
                 "conv2_1" : 0.8,
                 "conv3_1" : 0.4,
                 "conv4_1" : 0.2,
                 "conv5_1" : 0.1}
#more than content extractor, do exp

# %%
#calculate gram matrices for style feature
style_grams = {layer:gram_matrix(style_features[layer]) for layer in style_features}

# %%
content_wt = 100
style_wt = 1e8
#hyperparmeter-alpha beta

# %%
print_after = 500
epochs = 1000
optimizer = torch.optim.Adam([target],lr=0.007)

# %%
#optimize target
for i in range(1,epochs+1):
    target_features = model_activations(target,model)
    content_loss = torch.mean((content_features['conv4_2']-target_features['conv4_2'])**2)

    style_loss = 0
    for layer in style_wt_meas:
        style_gram = style_grams[layer]
        target_gram = target_features[layer]
        _,d,w,h = target_gram.shape
        target_gram = gram_matrix(target_gram)

        style_loss += (style_wt_meas[layer]*torch.mean((target_gram-style_gram)**2))/d*w*h
    
    total_loss = content_wt*content_loss + style_wt*style_loss 
    
    if i%10==0:       
        print("epoch ",i," ", total_loss)
    
    optimizer.zero_grad()
    total_loss.backward()
    optimizer.step()
    
    if i%print_after == 0:
        plt.imshow(imcnvt(target),label="Epoch "+str(i))
        plt.show()
        plt.imsave(str(i)+'.png',imcnvt(target),format='png')
# Out:
# epoch  10   tensor(4.7873e+18, grad_fn=<AddBackward0>)
# epoch  20   tensor(2.3338e+18, grad_fn=<AddBackward0>)
# epoch  30   tensor(1.2228e+18, grad_fn=<AddBackward0>)
# epoch  40   tensor(7.3736e+17, grad_fn=<AddBackward0>)
# epoch  50   tensor(5.1312e+17, grad_fn=<AddBackward0>)
# epoch  60   tensor(4.0287e+17, grad_fn=<AddBackward0>)
# epoch  70   tensor(3.4114e+17, grad_fn=<AddBackward0>)
# epoch  80   tensor(3.0199e+17, grad_fn=<AddBackward0>)
# epoch  90   tensor(2.7394e+17, grad_fn=<AddBackward0>)
# epoch  100   tensor(2.5218e+17, grad_fn=<AddBackward0>)
# epoch  110   tensor(2.3432e+17, grad_fn=<AddBackward0>)
# epoch  120   tensor(2.1909e+17, grad_fn=<AddBackward0>)
# epoch  130   tensor(2.0583e+17, grad_fn=<AddBackward0>)
# epoch  140   tensor(1.9411e+17, grad_fn=<AddBackward0>)
# epoch  150   tensor(1.8364e+17, grad_fn=<AddBackward0>)
# epoch  160   tensor(1.7420e+17, grad_fn=<AddBackward0>)
# epoch  170   tensor(1.6563e+17, grad_fn=<AddBackward0>)
# epoch  180   tensor(1.5780e+17, grad_fn=<AddBackward0>)
# epoch  190   tensor(1.5061e+17, grad_fn=<AddBackward0>)
# epoch  200   tensor(1.4399e+17, grad_fn=<AddBackward0>)
# epoch  210   tensor(1.3787e+17, grad_fn=<AddBackward0>)
# epoch  220   tensor(1.3219e+17, grad_fn=<AddBackward0>)
# epoch  230   tensor(1.2690e+17, grad_fn=<AddBackward0>)
# epoch  240   tensor(1.2197e+17, grad_fn=<AddBackward0>)
# epoch  250   tensor(1.1736e+17, grad_fn=<AddBackward0>)
# epoch  260   tensor(1.1305e+17, grad_fn=<AddBackward0>)
# epoch  270   tensor(1.0901e+17, grad_fn=<AddBackward0>)
# epoch  280   tensor(1.0520e+17, grad_fn=<AddBackward0>)
# epoch  290   tensor(1.0160e+17, grad_fn=<AddBackward0>)
# epoch  300   tensor(9.8200e+16, grad_fn=<AddBackward0>)
# epoch  310   tensor(9.4972e+16, grad_fn=<AddBackward0>)
# epoch  320   tensor(9.1907e+16, grad_fn=<AddBackward0>)
# epoch  330   tensor(8.8994e+16, grad_fn=<AddBackward0>)
# epoch  340   tensor(8.6217e+16, grad_fn=<AddBackward0>)
# epoch  350   tensor(8.3574e+16, grad_fn=<AddBackward0>)
# epoch  360   tensor(8.1063e+16, grad_fn=<AddBackward0>)
# epoch  370   tensor(7.8676e+16, grad_fn=<AddBackward0>)
# epoch  380   tensor(7.6406e+16, grad_fn=<AddBackward0>)
# epoch  390   tensor(7.4244e+16, grad_fn=<AddBackward0>)
# epoch  400   tensor(7.2186e+16, grad_fn=<AddBackward0>)
# epoch  410   tensor(7.0225e+16, grad_fn=<AddBackward0>)
# epoch  420   tensor(6.8360e+16, grad_fn=<AddBackward0>)
# epoch  430   tensor(6.6581e+16, grad_fn=<AddBackward0>)
# epoch  440   tensor(6.4885e+16, grad_fn=<AddBackward0>)
# epoch  450   tensor(6.3266e+16, grad_fn=<AddBackward0>)
# epoch  460   tensor(6.1717e+16, grad_fn=<AddBackward0>)
# epoch  470   tensor(6.0238e+16, grad_fn=<AddBackward0>)
# epoch  480   tensor(5.8828e+16, grad_fn=<AddBackward0>)
# epoch  490   tensor(5.7479e+16, grad_fn=<AddBackward0>)
# epoch  500   tensor(5.6188e+16, grad_fn=<AddBackward0>)
# epoch  510   tensor(5.4953e+16, grad_fn=<AddBackward0>)
# epoch  520   tensor(5.3774e+16, grad_fn=<AddBackward0>)
# epoch  530   tensor(5.2649e+16, grad_fn=<AddBackward0>)
# epoch  540   tensor(5.1570e+16, grad_fn=<AddBackward0>)
# epoch  550   tensor(5.0534e+16, grad_fn=<AddBackward0>)
# epoch  560   tensor(4.9538e+16, grad_fn=<AddBackward0>)
# epoch  570   tensor(4.8584e+16, grad_fn=<AddBackward0>)
# epoch  580   tensor(4.7667e+16, grad_fn=<AddBackward0>)
# epoch  590   tensor(4.6787e+16, grad_fn=<AddBackward0>)
# epoch  600   tensor(4.5943e+16, grad_fn=<AddBackward0>)
# epoch  610   tensor(4.5135e+16, grad_fn=<AddBackward0>)
# epoch  620   tensor(4.4359e+16, grad_fn=<AddBackward0>)
# epoch  630   tensor(4.3612e+16, grad_fn=<AddBackward0>)
# epoch  640   tensor(4.2893e+16, grad_fn=<AddBackward0>)
# epoch  650   tensor(4.2203e+16, grad_fn=<AddBackward0>)
# epoch  660   tensor(4.1540e+16, grad_fn=<AddBackward0>)
# epoch  670   tensor(4.0902e+16, grad_fn=<AddBackward0>)
# epoch  680   tensor(4.0289e+16, grad_fn=<AddBackward0>)
# epoch  690   tensor(3.9697e+16, grad_fn=<AddBackward0>)
# epoch  700   tensor(3.9126e+16, grad_fn=<AddBackward0>)
# epoch  710   tensor(3.8573e+16, grad_fn=<AddBackward0>)
# epoch  720   tensor(3.8035e+16, grad_fn=<AddBackward0>)
# epoch  730   tensor(3.7514e+16, grad_fn=<AddBackward0>)
# epoch  740   tensor(3.7009e+16, grad_fn=<AddBackward0>)
# epoch  750   tensor(3.6519e+16, grad_fn=<AddBackward0>)
# epoch  760   tensor(3.6045e+16, grad_fn=<AddBackward0>)
# epoch  770   tensor(3.5584e+16, grad_fn=<AddBackward0>)
# epoch  780   tensor(3.5135e+16, grad_fn=<AddBackward0>)
# epoch  790   tensor(3.4699e+16, grad_fn=<AddBackward0>)
# epoch  800   tensor(3.4275e+16, grad_fn=<AddBackward0>)
# epoch  810   tensor(3.3862e+16, grad_fn=<AddBackward0>)
# epoch  820   tensor(3.3462e+16, grad_fn=<AddBackward0>)
# epoch  830   tensor(3.3073e+16, grad_fn=<AddBackward0>)
# epoch  840   tensor(3.2695e+16, grad_fn=<AddBackward0>)
# epoch  850   tensor(3.2327e+16, grad_fn=<AddBackward0>)
# epoch  860   tensor(3.1970e+16, grad_fn=<AddBackward0>)
# epoch  870   tensor(3.1621e+16, grad_fn=<AddBackward0>)
# epoch  880   tensor(3.1281e+16, grad_fn=<AddBackward0>)
# epoch  890   tensor(3.0953e+16, grad_fn=<AddBackward0>)
# epoch  900   tensor(3.0634e+16, grad_fn=<AddBackward0>)
# epoch  910   tensor(3.0324e+16, grad_fn=<AddBackward0>)
# epoch  920   tensor(3.0023e+16, grad_fn=<AddBackward0>)
# epoch  930   tensor(2.9730e+16, grad_fn=<AddBackward0>)
# epoch  940   tensor(2.9444e+16, grad_fn=<AddBackward0>)
# epoch  950   tensor(2.9166e+16, grad_fn=<AddBackward0>)
# epoch  960   tensor(2.8898e+16, grad_fn=<AddBackward0>)
# epoch  970   tensor(2.8637e+16, grad_fn=<AddBackward0>)
# epoch  980   tensor(2.8384e+16, grad_fn=<AddBackward0>)
# epoch  990   tensor(2.8136e+16, grad_fn=<AddBackward0>)
# epoch  1000   tensor(2.7894e+16, grad_fn=<AddBackward0>)
